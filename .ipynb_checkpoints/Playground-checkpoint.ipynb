# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('cell_10000.png')

# %%
img
# Out:
# array([[ 0.07058824,  0.15294118,  0.07450981, ...,  0.10980392,
#          0.12156863,  0.11764706],
#        [ 0.08627451,  0.16078432,  0.09803922, ...,  0.03529412,
#          0.06666667,  0.07450981],
#        [ 0.07058824,  0.09803922,  0.05490196, ...,  0.04705882,
#          0.08627451,  0.07450981],
#        ...,
#        [ 0.05490196,  0.06666667,  0.14117648, ...,  0.07843138,
#          0.07058824,  0.10588235],
#        [ 0.05098039,  0.04313726,  0.10196079, ...,  0.06666667,
#          0.06666667,  0.05098039],
#        [ 0.04705882,  0.07450981,  0.22352941, ...,  0.09019608,
#          0.08627451,  0.07450981]], dtype=float32)

# %%
im_out = plt.imshow(img)

# %%
from PIL import Image, ImageTk
import os

# %%
path = os.getcwd() + '/cell_10000.png'

# %%
path
# Out:
# '/Users/jakesell/Documents/Centrosome-Tracking/cell_10000.png'

# %%
im = Image.open(path)
w, h = im.size
img = im.load()
pixels = []
for x in range(w):
    for y in range(h):
        pixels.append(img[x,y])

# %%
pix = np.array(im)
r,c = pix.size
d_pix = np.empty_like(pix)

for x in range(r):
    for y in range(c):
        d_pix[x][y] = float(pix[x][y])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-8695c675c525> in <module>()
#       1 pix = np.array(im)
# ----> 2 r,c = pix.size
#       3 d_pix = np.empty_like(pix)
#       4
#       5 for x in range(r):
#
# TypeError: 'int' object is not iterable

# %%
pix = np.array(im)

# %%
pix[0]

# %%
pix

# %%
i = Image.fromarray(pix)

# %%
i
# Out:
# <PIL.Image.Image image mode=L size=352x236 at 0x10DD7E940>

# %%
f = np.fft.fft(pix)

# %%
av_f = 2*np.mean(abs(f))

# %%
f[abs(f) < av_f] = 0

# %%
i_f = np.fft.ifft(f)

# %%
i_f = i_f.real

# %%
plt.imshow(i_f.astype(np.uint8))

# %%
Image.fromarray(i_f.astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=L size=352x236 at 0x112455EF0>

# %%
pix[0,:].mean()
# Out:
# 23.19034090909091

# %%
avg=pix.mean(axis=1)

# %%
r = (pix.T-avg).T

# %%
c = np.cov(r)

# %%
val, vec = np.linalg.eig(c)

# %%
vec
# Out:
# array([[-0.00359861, -0.00761444, -0.00534998, ..., -0.07079555,
#         -0.02939557, -0.00207971],
#        [ 0.00109249,  0.00069431, -0.0138181 , ...,  0.00895047,
#         -0.08293034,  0.04378345],
#        [ 0.0005405 , -0.0043792 , -0.0081529 , ...,  0.05809157,
#          0.12094905, -0.0081123 ],
#        ...,
#        [ 0.00343593, -0.00269883, -0.01164312, ...,  0.02911432,
#          0.01124887,  0.03088943],
#        [ 0.00294729, -0.00275945, -0.02010605, ...,  0.00233846,
#         -0.04027598,  0.06044598],
#        [-0.0023606 , -0.00314977, -0.00111291, ..., -0.03646505,
#          0.01788773,  0.01129324]])

# %%
srtd = np.sort(vec, axis =0)

# %%
test = [2, 3, 42, 34]

# %%
np.sort(test, axis = 0)
# Out:
# array([ 2,  3, 34, 42])

# %%
half = len(srtd)/2

# %%
from scipy import ndimage

# %%
gauss = ndimage.gaussian_filter(i_f.astype(np.uint8), 2)

# %%
Image.fromarray(gauss)
# Out:
# <PIL.Image.Image image mode=L size=352x236 at 0x116506B38>

# %%
gauss[gauss<100]=0

# %%
Image.fromarray(gauss)
# Out:
# <PIL.Image.Image image mode=L size=352x236 at 0x116506DA0>
